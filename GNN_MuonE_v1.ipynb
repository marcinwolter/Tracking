# %% [markdown]
# <a href="https://colab.research.google.com/github/marcinwolter/Tracking/blob/master/GNN_MuonE_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tutorial: GNNs for Particle Tracking
#
# HEP.TrkX group
#
# Steve Farrell, Daniel Murname
#
# *Feb 2020*
#
# Adapted for MuonE tracking by Marcin Wolter
#
# *July 2020*

# %%
# System imports
import os
import sys
from pprint import pprint as pp
from time import time as tt

# External imports
import matplotlib.pyplot as plt
import matplotlib.colors
import numpy as np
import pandas as pd
import seaborn as sns
import torch

# %%
print("PyTorch version:",print(torch.__version__),", CUDA version:", torch.version.cuda)
# Out:
# 1.5.1+cu101
# PyTorch version: None , CUDA version: 10.1

# %%
# !pip install torch-scatter==latest+cu101 torch-sparse==latest+cu101 -f https://s3.eu-central-1.amazonaws.com/pytorch-geometric.com/whl/torch-1.5.0.html
# !pip install torch-geometric
# Out:
# Looking in links: https://s3.eu-central-1.amazonaws.com/pytorch-geometric.com/whl/torch-1.5.0.html
# Collecting torch-scatter==latest+cu101
#   Using cached https://pytorch-geometric.com/whl/torch-1.5.0/torch_scatter-latest%2Bcu101-cp36-cp36m-linux_x86_64.whl
# Collecting torch-sparse==latest+cu101
#   Using cached https://pytorch-geometric.com/whl/torch-1.5.0/torch_sparse-latest%2Bcu101-cp36-cp36m-linux_x86_64.whl
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from torch-sparse==latest+cu101) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scipy->torch-sparse==latest+cu101) (1.18.5)
# Installing collected packages: torch-scatter, torch-sparse
#   Found existing installation: torch-scatter 2.0.5
#     Uninstalling torch-scatter-2.0.5:
#       Successfully uninstalled torch-scatter-2.0.5
#   Found existing installation: torch-sparse 0.6.6
#     Uninstalling torch-sparse-0.6.6:
#       Successfully uninstalled torch-sparse-0.6.6
# Successfully installed torch-scatter-2.0.5 torch-sparse-0.6.6
# Requirement already satisfied: torch-geometric in /usr/local/lib/python3.6/dist-packages (1.6.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (2.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (1.18.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (2.10.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (4.41.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (1.5.1+cu101)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (1.0.5)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: ase in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (3.19.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (0.48.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (1.4.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (2.11.2)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (5.0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from torch-geometric) (0.22.2.post1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->torch-geometric) (4.4.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->torch-geometric) (1.12.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->torch-geometric) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->torch-geometric) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->torch-geometric) (2018.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->torch-geometric) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torch-geometric) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torch-geometric) (1.24.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from ase->torch-geometric) (3.2.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from numba->torch-geometric) (47.3.1)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba->torch-geometric) (0.31.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->torch-geometric) (1.1.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from rdflib->torch-geometric) (2.4.7)
# Requirement already satisfied: isodate in /usr/local/lib/python3.6/dist-packages (from rdflib->torch-geometric) (0.6.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->torch-geometric) (0.15.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib->ase->torch-geometric) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->ase->torch-geometric) (1.2.0)

# %%
from torch_geometric.data import Data
from torch_geometric.data import DataLoader
import torch.nn as nn
from torch_scatter import scatter_add
import torch.nn.functional as F

import ipywidgets as widgets
from ipywidgets import interact, interact_manual
from IPython.display import clear_output
from IPython.display import HTML, display

# %matplotlib inline

# Get rid of RuntimeWarnings, gross
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %% [markdown]
# ## The Problem

# %% [markdown]
# ### Toy Data

# %%
# Circle parameters
num_layers = 4 #10
height, width = 4, 4 #10, 10
min_curve, max_curve =  15, 50
noise = False
event_size_min, event_size_max = 2, 3 #4, 12 #I.E. The number of true particle tracks
max_angle= (5/6)*np.pi  # (4/6)*np.pi
feature_scale = np.array([10,10])

# %%
# Some dumb circle calculations
def y1(x, r, a, sign):
    return sign*np.sqrt(r**2 - a**2) + np.sqrt(r**2 - (x-a)**2)
def y2(x, r, a, sign):
    return sign*np.sqrt(r**2 - a**2) - np.sqrt(r**2 - (x-a)**2)

# Generate random circle / helix parameters
def rand_pars(event_size_min, event_size_max, max_curve, min_curve):
    event_size = int(np.floor(np.random.random(1)*(event_size_max - event_size_min) + event_size_min))
    radii = np.random.random(event_size)*(max_curve - min_curve) + min_curve
    dirs = np.random.random(event_size)*(radii)*2 -radii
    sign_options = np.array([-1,1])
    signs = sign_options[np.rint(np.random.random(event_size)).astype(int)]
    return radii, dirs, signs, event_size

def progress(value, max=100):
    return HTML("""
        <progress
            value='{value}'
            max='{max}',
            style='width: 100%'
        >
            {value}
        </progress>
    """.format(value=value, max=max))

# Generate event data from random parameters
def gen_edge_class(event_size_min, event_size_max, curve_min, curve_max, height, num_layers, max_angle, feature_scale, iter, num_samples):
    
    """ Feed params into randomiser """
    while True:
        radii, dirs, signs, event_size = rand_pars(event_size_min, event_size_max, curve_max, curve_min)
        xys = []
        X = np.empty([3,1])
        x = np.arange(0 + height/num_layers,height + height/num_layers, height/num_layers)
        i = 0
        for r, d, s in zip(radii, dirs, signs):
            y1test = y1(x, r, d, s)
            y2test = y2(x, r, d, s)
            #print(y1test,y2test, x)
            if -2.5 < y1test[0] < 2.5 and not any(np.isnan(y1test)):
                X = np.append(X, np.vstack((y1test, np.array([i]*len(y1test)), x )), axis=1)
                i += 1
            if -2.5 < y2test[0] < 2.5 and not any(np.isnan(y2test)):
                X = np.append(X, np.vstack((y2test, np.array([i]*len(y2test)), x )), axis=1)
                i += 1
        #print(" X ",X)       
        X = X[:,1:].T
        #print("X.T ",X)
        np.random.shuffle(X)

        e = np.array([[i,j] for layer in np.arange(num_layers-1) for i in np.argwhere(X[:,2] == layer+1) for j in np.argwhere(X[:,2] == (layer+2)) if (X[i, 0] - np.tan(max_angle/2) < X[j, 0] < X[i, 0] + np.tan(max_angle/2))]).T.squeeze()
        #print("X = ",X)
        #print("e = ",e)

        # This handles when no edges were constructed. In that case, the randomisation is a do-over
        try:
            y = np.array([int(i[1] == j[1]) for i,j in zip(X[e[0]], X[e[1]])])    
            break
        except:
            pass
    if iter is not None and num_samples is not None:
        out.update(progress(iter, num_samples))    
    
    X = np.array([X[:,2], X[:,0]]).T / feature_scale

    data = Data(x = torch.from_numpy(X).float(), edge_index = torch.from_numpy(e), y = torch.from_numpy(y), pid = torch.from_numpy(X[:,1]))
    return data

# %%
def plot_toy_graph(event, ylim=1.):
  
    #print(event)
    #print(event.x)
    #print(event.pid)
    #print(event.y)

    plt.figure(figsize=(10,5))
    x, y = event.x[:,0].numpy(), event.x[:,1].numpy()
    e = event.edge_index.numpy()
#     for i, j in zip(X[e[0]], X[e[1]]):
#         plt.plot([i[0], j[0]], [i[1], j[1]], c='b')
    #     print(i[0], i[2], j[0], j[2])
    plt.plot([x[e[0,:]], x[e[1,:]]], [y[e[0,:]], y[e[1,:]]], c='b')
    plt.scatter(x, y, c='k')
    plt.ylim(-ylim,ylim)

# %%
train_size, test_size = 1000, 1000
out = display(progress(0, train_size), display_id=True)
train_dataset = [gen_edge_class(event_size_min, event_size_max, max_curve, min_curve, height, num_layers, max_angle, feature_scale, i, train_size) for i in range(train_size)]
out = display(progress(0, test_size), display_id=True)
test_dataset = [gen_edge_class(event_size_min, event_size_max, max_curve, min_curve, height, num_layers, max_angle, feature_scale, i, test_size) for i in range(test_size)]
train_loader = DataLoader(train_dataset, batch_size=100, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=100, shuffle=True)
# Out:
#         <progress
#             value='999'
#             max='1000',
#             style='width: 100%'
#         >
#             999
#         </progress>
#         <progress
#             value='999'
#             max='1000',
#             style='width: 100%'
#         >
#             999
#         </progress>

# %%
for k in range(10):
   plot_toy_graph(test_dataset[k])

# %% [markdown]
# The complexity of the graph depends on the angle cut we put on it. Try increasing max_angle to, say, `(5/6)*np.pi` and the graph should be more busy. The limit is of course `(6/6)*np.pi = pi` where each node will look at the full angle of available possible nodes to form an edge with. While playing with this number, run the next cell to see the proportion of fake edges to true edges (fake/true) on the above graph. This value will be extremely useful later.

# %%
print("Fake / True = ", (len(train_dataset[0].y) - train_dataset[0].y.sum().item()) / train_dataset[0].y.sum().item())
# Out:
# Fake / True =  0.0

# %% [markdown]
# ## A Simple GNN

# %% [markdown]
# ### Message Passing GNN

# %% [markdown]
# We can write out the full GNN as a class `MPNN_Network`. One can see its behaviour as:
# 1. Encode (x,y) features as hidden features with an N-layer MLP called `node_encoder`
# 2. Concatenate these along each edge, and feed the concatenated features into another MLP called `edge_network`
# 3. Sum the output of `edge_classifier` at each node (that is, each node receives the sum of the "messages" of all connecting edges). This sum is fed into `node_network`
# 4. Add the hidden features to the previous iteration (this helps to preserve information between messages)
# 5. Repeat (2) --> (4) n_graph_iters times
# 6. After the message passing loop, pass the features of each edge through an output classifier network called `edge_classifier`

# %%
def make_mlp(input_size, sizes,
             hidden_activation='ReLU',
             output_activation='ReLU',
             layer_norm=False):
    """Construct an MLP with specified fully-connected layers."""
    hidden_activation = getattr(nn, hidden_activation)
    if output_activation is not None:
        output_activation = getattr(nn, output_activation)
    layers = []
    n_layers = len(sizes)
    sizes = [input_size] + sizes
    # Hidden layers
    for i in range(n_layers-1):
        layers.append(nn.Linear(sizes[i], sizes[i+1]))
        if layer_norm:
            layers.append(nn.LayerNorm(sizes[i+1]))
        layers.append(hidden_activation())
    # Final layer
    layers.append(nn.Linear(sizes[-2], sizes[-1]))
    if output_activation is not None:
        if layer_norm:
            layers.append(nn.LayerNorm(sizes[-1]))
        layers.append(output_activation())
    return nn.Sequential(*layers)

class MPNN_Network(nn.Module):
    """
    A message-passing graph network which takes a graph with:
    - bi-directional edges
    - node features, no edge features

    and applies the following modules:
    - a graph encoder (no message passing)
    - recurrent edge and node networks
    - an edge classifier
    """

    def __init__(self, input_dim, hidden_node_dim, hidden_edge_dim, in_layers, node_layers, edge_layers,
                 n_graph_iters=1, layer_norm=True):
        super(MPNN_Network, self).__init__()
        self.n_graph_iters = n_graph_iters

        # The node encoder transforms input node features to the hidden space
        self.node_encoder = make_mlp(input_dim, [hidden_node_dim]*in_layers)

        # The edge network computes new edge features from connected nodes
        self.edge_network = make_mlp(2*hidden_node_dim,
                                     [hidden_edge_dim]*edge_layers,
                                     layer_norm=layer_norm)

        # The node network computes new node features
        self.node_network = make_mlp(hidden_node_dim + hidden_edge_dim,
                                     [hidden_node_dim]*node_layers,
                                     layer_norm=layer_norm)

        # The edge classifier computes final edge scores
        self.edge_classifier = make_mlp(2*hidden_node_dim,
                                        [hidden_edge_dim, 1],
                                        output_activation=None)

    def forward(self, data):
        # Make every edge bi-directional
        send_idx = torch.cat([data.edge_index[0], data.edge_index[1]], dim=0)
        recv_idx = torch.cat([data.edge_index[1], data.edge_index[0]], dim=0)

        # Encode the graph features into the hidden space
        x = self.node_encoder(data.x)

        # Loop over graph iterations
        for i in range(self.n_graph_iters):

            # Previous hidden state
            x0 = x

            # Compute new edge features
            edge_inputs = torch.cat([x[send_idx], x[recv_idx]], dim=1)
            e = self.edge_network(edge_inputs)

            # Sum edge features coming into each node
            aggr_messages = scatter_add(e, recv_idx, dim=0, dim_size=x.shape[0])

            # Compute new node features
            node_inputs = torch.cat([x, aggr_messages], dim=1)
            x = self.node_network(node_inputs)

            # Residual connection
            x = x + x0

        # Compute final edge scores; use original edge directions only
        start_idx, end_idx = data.edge_index
        clf_inputs = torch.cat([x[start_idx], x[end_idx]], dim=1)
        return self.edge_classifier(clf_inputs).squeeze(-1)

# %% [markdown]
# Build a version of the model and print it out.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
m_configs = {"input_dim": 2, "hidden_node_dim": 64, "hidden_edge_dim": 64, "in_layers": 2, "node_layers": 4, "edge_layers": 4, "n_graph_iters": 1, "layer_norm": True}
model = MPNN_Network(**m_configs).to(device)
model
# Out:
# MPNN_Network(
#   (node_encoder): Sequential(
#     (0): Linear(in_features=2, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ReLU()
#   )
#   (edge_network): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=64, bias=True)
#     (7): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (8): ReLU()
#     (9): Linear(in_features=64, out_features=64, bias=True)
#     (10): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (11): ReLU()
#   )
#   (node_network): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=64, bias=True)
#     (7): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (8): ReLU()
#     (9): Linear(in_features=64, out_features=64, bias=True)
#     (10): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (11): ReLU()
#   )
#   (edge_classifier): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ### Training on Toy Data

# %%
def train(model, train_loader, optimizer):
    correct = 0
    total = 0
    total_loss = 0
    for batch in train_loader:
        optimizer.zero_grad()
        data = batch.to(device)
        pred = model(data)
        loss = F.binary_cross_entropy_with_logits(pred.float(), data.y.float(), pos_weight=torch.tensor(weight))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        correct += ((pred > 0.5) == (data.y > 0.5)).sum().item()
        total += len(pred)
    acc = correct/total
    return acc, total_loss

def evaluate(model, test_loader):
    correct = 0
    total = 0
    total_loss = 0
    for batch in test_loader:
        data = batch.to(device)
        pred = model(data)
        loss = F.binary_cross_entropy_with_logits(pred.float(), data.y.float(), pos_weight=torch.tensor(weight))
        total_loss += loss.item()
        correct += ((pred > 0.5) == (data.y > 0.5)).sum().item()
        total += len(pred)
    acc = correct/total
    return acc, total_loss

# %%
t_loss_v = []
t_acc_v = []
v_loss_v = []
v_acc_v = []
ep = 0

# %% [markdown]
# We set a weight value that is more or less the (fake / true) ratio found above. This forces the loss function to punish incorrectly classified true edges more severely. It rebalances the distribution as if there was a 1:1 true:fake ratio.

# %%
weight = 2

m_configs = {"input_dim": 2, "hidden_node_dim": 16, "hidden_edge_dim": 16, "in_layers": 1, "node_layers": 2, "edge_layers": 2, "n_graph_iters": 6, "layer_norm": True}
model = MPNN_Network(**m_configs).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-3, amsgrad=True)

for epoch in range(200):
    ep += 1  
    model.train()
    acc, total_loss = train(model, train_loader, optimizer)
    t_loss_v.append(total_loss)
    t_acc_v.append(acc)

    model.eval()
    acc, total_loss = evaluate(model, test_loader)
    v_loss_v.append(total_loss)
    v_acc_v.append(acc)

    print('Epoch: {}, Accuracy: {:.4f}'.format(ep, acc))
# Out:
# Epoch: 1, Accuracy: 0.5873
# Epoch: 2, Accuracy: 0.5873
# Epoch: 3, Accuracy: 0.5873
# Epoch: 4, Accuracy: 0.5873
# Epoch: 5, Accuracy: 0.5873
# Epoch: 6, Accuracy: 0.5865
# Epoch: 7, Accuracy: 0.5878
# Epoch: 8, Accuracy: 0.5877
# Epoch: 9, Accuracy: 0.5874
# Epoch: 10, Accuracy: 0.5830
# Epoch: 11, Accuracy: 0.5858
# Epoch: 12, Accuracy: 0.5835
# Epoch: 13, Accuracy: 0.5861
# Epoch: 14, Accuracy: 0.6016
# Epoch: 15, Accuracy: 0.5873
# Epoch: 16, Accuracy: 0.6062
# Epoch: 17, Accuracy: 0.6094
# Epoch: 18, Accuracy: 0.6287
# Epoch: 19, Accuracy: 0.6155
# Epoch: 20, Accuracy: 0.6310
# Epoch: 21, Accuracy: 0.6287
# Epoch: 22, Accuracy: 0.6315
# Epoch: 23, Accuracy: 0.6167
# Epoch: 24, Accuracy: 0.5742
# Epoch: 25, Accuracy: 0.6464
# Epoch: 26, Accuracy: 0.6521
# Epoch: 27, Accuracy: 0.6284
# Epoch: 28, Accuracy: 0.6693
# Epoch: 29, Accuracy: 0.6724
# Epoch: 30, Accuracy: 0.6617
# Epoch: 31, Accuracy: 0.6728
# Epoch: 32, Accuracy: 0.6439
# Epoch: 33, Accuracy: 0.6722
# Epoch: 34, Accuracy: 0.6910
# Epoch: 35, Accuracy: 0.6702
# Epoch: 36, Accuracy: 0.6899
# Epoch: 37, Accuracy: 0.7075
# Epoch: 38, Accuracy: 0.6324
# Epoch: 39, Accuracy: 0.6964
# Epoch: 40, Accuracy: 0.7329
# Epoch: 41, Accuracy: 0.8022
# Epoch: 42, Accuracy: 0.8538
# Epoch: 43, Accuracy: 0.8802
# Epoch: 44, Accuracy: 0.9304
# Epoch: 45, Accuracy: 0.9389
# Epoch: 46, Accuracy: 0.9496
# Epoch: 47, Accuracy: 0.9501
# Epoch: 48, Accuracy: 0.9656
# Epoch: 49, Accuracy: 0.9622
# Epoch: 50, Accuracy: 0.9494
# Epoch: 51, Accuracy: 0.9688
# Epoch: 52, Accuracy: 0.9710
# Epoch: 53, Accuracy: 0.9748
# Epoch: 54, Accuracy: 0.9766
# Epoch: 55, Accuracy: 0.9771
# Epoch: 56, Accuracy: 0.9798
# Epoch: 57, Accuracy: 0.9759
# Epoch: 58, Accuracy: 0.9780
# Epoch: 59, Accuracy: 0.9787
# Epoch: 60, Accuracy: 0.9794
# Epoch: 61, Accuracy: 0.9839
# Epoch: 62, Accuracy: 0.9789
# Epoch: 63, Accuracy: 0.9806
# Epoch: 64, Accuracy: 0.9789
# Epoch: 65, Accuracy: 0.9794
# Epoch: 66, Accuracy: 0.9847
# Epoch: 67, Accuracy: 0.9753
# Epoch: 68, Accuracy: 0.9840
# Epoch: 69, Accuracy: 0.9810
# Epoch: 70, Accuracy: 0.9821
# Epoch: 71, Accuracy: 0.9786
# Epoch: 72, Accuracy: 0.9819
# Epoch: 73, Accuracy: 0.9842
# Epoch: 74, Accuracy: 0.9852
# Epoch: 75, Accuracy: 0.9780
# Epoch: 76, Accuracy: 0.9845
# Epoch: 77, Accuracy: 0.9803
# Epoch: 78, Accuracy: 0.9802
# Epoch: 79, Accuracy: 0.9854
# Epoch: 80, Accuracy: 0.9867
# Epoch: 81, Accuracy: 0.9854
# Epoch: 82, Accuracy: 0.9851
# Epoch: 83, Accuracy: 0.9739
# Epoch: 84, Accuracy: 0.9848
# Epoch: 85, Accuracy: 0.9860
# Epoch: 86, Accuracy: 0.9839
# Epoch: 87, Accuracy: 0.9859
# Epoch: 88, Accuracy: 0.9865
# Epoch: 89, Accuracy: 0.9851
# Epoch: 90, Accuracy: 0.9847
# Epoch: 91, Accuracy: 0.9859
# Epoch: 92, Accuracy: 0.9864
# Epoch: 93, Accuracy: 0.9872
# Epoch: 94, Accuracy: 0.9870
# Epoch: 95, Accuracy: 0.9860
# Epoch: 96, Accuracy: 0.9802
# Epoch: 97, Accuracy: 0.9861
# Epoch: 98, Accuracy: 0.9855
# Epoch: 99, Accuracy: 0.9866
# Epoch: 100, Accuracy: 0.9873
# Epoch: 101, Accuracy: 0.9873
# Epoch: 102, Accuracy: 0.9866
# Epoch: 103, Accuracy: 0.9859
# Epoch: 104, Accuracy: 0.9872
# Epoch: 105, Accuracy: 0.9872
# Epoch: 106, Accuracy: 0.9858
# Epoch: 107, Accuracy: 0.9869
# Epoch: 108, Accuracy: 0.9843
# Epoch: 109, Accuracy: 0.9873
# Epoch: 110, Accuracy: 0.9865
# Epoch: 111, Accuracy: 0.9868
# Epoch: 112, Accuracy: 0.9844
# Epoch: 113, Accuracy: 0.9857
# Epoch: 114, Accuracy: 0.9856
# Epoch: 115, Accuracy: 0.9845
# Epoch: 116, Accuracy: 0.9858
# Epoch: 117, Accuracy: 0.9845
# Epoch: 118, Accuracy: 0.9867
# Epoch: 119, Accuracy: 0.9871
# Epoch: 120, Accuracy: 0.9870
# Epoch: 121, Accuracy: 0.9864
# Epoch: 122, Accuracy: 0.9876
# Epoch: 123, Accuracy: 0.9879
# Epoch: 124, Accuracy: 0.9864
# Epoch: 125, Accuracy: 0.9881
# Epoch: 126, Accuracy: 0.9864
# Epoch: 127, Accuracy: 0.9871
# Epoch: 128, Accuracy: 0.9860
# Epoch: 129, Accuracy: 0.9877
# Epoch: 130, Accuracy: 0.9741
# Epoch: 131, Accuracy: 0.9820
# Epoch: 132, Accuracy: 0.9826
# Epoch: 133, Accuracy: 0.9841
# Epoch: 134, Accuracy: 0.9872
# Epoch: 135, Accuracy: 0.9850
# Epoch: 136, Accuracy: 0.9879
# Epoch: 137, Accuracy: 0.9880
# Epoch: 138, Accuracy: 0.9879
# Epoch: 139, Accuracy: 0.9882
# Epoch: 140, Accuracy: 0.9879
# Epoch: 141, Accuracy: 0.9879
# Epoch: 142, Accuracy: 0.9892
# Epoch: 143, Accuracy: 0.9895
# Epoch: 144, Accuracy: 0.9877
# Epoch: 145, Accuracy: 0.9879
# Epoch: 146, Accuracy: 0.9878
# Epoch: 147, Accuracy: 0.9887
# Epoch: 148, Accuracy: 0.9887
# Epoch: 149, Accuracy: 0.9886
# Epoch: 150, Accuracy: 0.9877
# Epoch: 151, Accuracy: 0.9878
# Epoch: 152, Accuracy: 0.9882
# Epoch: 153, Accuracy: 0.9885
# Epoch: 154, Accuracy: 0.9884
# Epoch: 155, Accuracy: 0.9886
# Epoch: 156, Accuracy: 0.9885
# Epoch: 157, Accuracy: 0.9885
# Epoch: 158, Accuracy: 0.9885
# Epoch: 159, Accuracy: 0.9880
# Epoch: 160, Accuracy: 0.9878
# Epoch: 161, Accuracy: 0.9882
# Epoch: 162, Accuracy: 0.9874
# Epoch: 163, Accuracy: 0.9881
# Epoch: 164, Accuracy: 0.9866
# Epoch: 165, Accuracy: 0.9881
# Epoch: 166, Accuracy: 0.9880
# Epoch: 167, Accuracy: 0.9889
# Epoch: 168, Accuracy: 0.9874
# Epoch: 169, Accuracy: 0.9890
# Epoch: 170, Accuracy: 0.9883
# Epoch: 171, Accuracy: 0.9884
# Epoch: 172, Accuracy: 0.9882
# Epoch: 173, Accuracy: 0.9873
# Epoch: 174, Accuracy: 0.9877
# Epoch: 175, Accuracy: 0.9877
# Epoch: 176, Accuracy: 0.9881
# Epoch: 177, Accuracy: 0.9887
# Epoch: 178, Accuracy: 0.9885
# Epoch: 179, Accuracy: 0.9874
# Epoch: 180, Accuracy: 0.9883
# Epoch: 181, Accuracy: 0.9884
# Epoch: 182, Accuracy: 0.9887
# Epoch: 183, Accuracy: 0.9886
# Epoch: 184, Accuracy: 0.9885
# Epoch: 185, Accuracy: 0.9881
# Epoch: 186, Accuracy: 0.9876
# Epoch: 187, Accuracy: 0.9871
# Epoch: 188, Accuracy: 0.9878
# Epoch: 189, Accuracy: 0.9877
# Epoch: 190, Accuracy: 0.9873
# Epoch: 191, Accuracy: 0.9869
# Epoch: 192, Accuracy: 0.9889
# Epoch: 193, Accuracy: 0.9886
# Epoch: 194, Accuracy: 0.9874
# Epoch: 195, Accuracy: 0.9884
# Epoch: 196, Accuracy: 0.9874
# Epoch: 197, Accuracy: 0.9882
# Epoch: 198, Accuracy: 0.9867
# Epoch: 199, Accuracy: 0.9878
# Epoch: 200, Accuracy: 0.9882

# %%
fig, axs = plt.subplots(1, 2, constrained_layout=True, figsize=(10, 5))
axs[0].plot(np.arange(len(t_loss_v)), t_loss_v, np.arange(len(t_acc_v)), t_acc_v)
axs[0].set_title("Training loss and accuracy")
axs[0].set_yscale("linear")
axs[1].plot(np.arange(len(v_loss_v)), v_loss_v, np.arange(len(v_acc_v)), v_acc_v)
axs[1].set_title("Validation loss and accuracy")
axs[1].set_yscale("linear")

# %% [markdown]
# ### Did it work?

# %% [markdown]
# Running the above with 1 graph iteration gives me about 90% accuracy in 200 epochs.

# %% [markdown]
# The best performance that I can get with some simple manual tuning is around 95% accuracy. We can improve the efficiency at the cost of purity by raising the weight on true edges, but the accuracy won't significantly improve. In general, the biggest changes were from increasing the width (i.e. the number of dimensions) of the hidden layers. We can visualise the performance on a particular graph, colouring true positives black, false positives red, true negatives a transparent black, and false negatives in blue.

# %%
def plot_toy_classified(event, preds, cut=0.5):
    
    #print("New event")
        
    #print(event)
    #print(event.x)
    #print(event.pid)
    #print(event.y)
    #gprint(preds)

    plt.figure(figsize=(10,5))
    x, y = event.x[:,0].numpy(), event.x[:,1].numpy()
    edges = event.edge_index.numpy()
    labels = event.y
    plt.scatter(x, y, c='k')
    
    preds = preds.detach().numpy()
    

    for j in range(len(labels)):
        
        #print(str('%01.2f' % preds[j])+" "+str(labels[j].item())+" "+str(x[edges[0,j]]*feature_scale)+","+str(y[edges[0,j]]*feature_scale)+" "+str(x[edges[1,j]]*feature_scale)+","+str(y[edges[1,j]]*feature_scale))
        s = str('%01.2f' % preds[j])+" "+str(labels[j].item())
        plt.text((x[edges[0,j]]+x[edges[1,j]])/2., (y[edges[0,j]]+y[edges[1,j]])/2.+np.random.random(1)*0.00, s, fontsize=12)

        # False negatives
        if preds[j] < cut and labels[j].item() > cut:
            plt.plot([x[edges[0,j]], x[edges[1,j]]],
                     [y[edges[0,j]], y[edges[1,j]]],
                     '--', c='b')

        # False positives
        if preds[j] > cut and labels[j].item() < cut:
            plt.plot([x[edges[0,j]], x[edges[1,j]]],
                     [y[edges[0,j]], y[edges[1,j]]],
                     '-', c='r', alpha=preds[j])

        # True positives
        if preds[j] > cut and labels[j].item() > cut:
            plt.plot([x[edges[0,j]], x[edges[1,j]]],
                     [y[edges[0,j]], y[edges[1,j]]],
                     '-', c='k', alpha=preds[j])
                
        # True negatives
        if preds[j] < cut and labels[j].item() < cut:
            plt.plot([x[edges[0,j]], x[edges[1,j]]],
                     [y[edges[0,j]], y[edges[1,j]]],
                     '-', c='k', alpha=preds[j])

# %%
for k in range(10):
   data = test_loader.dataset[k].to(device)
   preds = torch.sigmoid(model(data)).to('cpu')
   plot_toy_classified(data.to('cpu'), preds, cut = 0.6)

# %% [markdown]
# So we can see that it's working quite well. Few missed true edges, and few misclassified fake edges. The ratio of false positives to false negatives (which can be defined with efficiency and purity) is controlled by the cut we put on the prediction score.

# %% [markdown]
# ### The effect of Message Passing

# %% [markdown]
# In this simple example, the message passing does not do a huge amount. Going from 1 iteration to 6 iterations improves the accuracy to around 93% (from 90%). This improvement is washed out with more hidden dimensions, as one can see from the below set of tests. Try playing with more hidden node and edge dimensions (e.g. 64) and see if the message passing iterations can improve the performance.

# %%
t_loss_v = []
t_acc_v = []
v_loss_v = []
v_acc_v = []
ep = 0
best_acc = np.zeros(10)
for i in range(1,2): #for i in range(1,11): # shorten to 2 iterations to speed up
    m_configs = {"input_dim": 2, "hidden_node_dim": 16, "hidden_edge_dim": 16, "in_layers": 1, "node_layers": 2, "edge_layers": 2, "n_graph_iters": i, "layer_norm": True}
    model = MPNN_Network(**m_configs).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-3, amsgrad=True)
    for epoch in range(200):
        ep += 1  
        model.train()
        acc, total_loss = train(model, train_loader, optimizer)
        t_loss_v.append(total_loss)
        t_acc_v.append(acc)

        model.eval()
        acc, total_loss = evaluate(model, test_loader)
        if acc > best_acc[i-1]: best_acc[i-1] = acc
        v_loss_v.append(total_loss)
        v_acc_v.append(acc)

        print('Epoch: {}, Accuracy: {:.4f}'.format(ep, acc))
plt.plot(np.arange(len(best_acc)), best_acc)
# Out:
# Epoch: 1, Accuracy: 0.4127
# Epoch: 2, Accuracy: 0.4250
# Epoch: 3, Accuracy: 0.5873
# Epoch: 4, Accuracy: 0.5873
# Epoch: 5, Accuracy: 0.5873
# Epoch: 6, Accuracy: 0.5873
# Epoch: 7, Accuracy: 0.5873
# Epoch: 8, Accuracy: 0.5873
# Epoch: 9, Accuracy: 0.5873
# Epoch: 10, Accuracy: 0.5873
# Epoch: 11, Accuracy: 0.5873
# Epoch: 12, Accuracy: 0.5873
# Epoch: 13, Accuracy: 0.5873
# Epoch: 14, Accuracy: 0.5873
# Epoch: 15, Accuracy: 0.5873
# Epoch: 16, Accuracy: 0.5873
# Epoch: 17, Accuracy: 0.5873
# Epoch: 18, Accuracy: 0.5873
# Epoch: 19, Accuracy: 0.5877
# Epoch: 20, Accuracy: 0.5882
# Epoch: 21, Accuracy: 0.5873
# Epoch: 22, Accuracy: 0.5880
# Epoch: 23, Accuracy: 0.5890
# Epoch: 24, Accuracy: 0.5892
# Epoch: 25, Accuracy: 0.5962
# Epoch: 26, Accuracy: 0.5946
# Epoch: 27, Accuracy: 0.6026
# Epoch: 28, Accuracy: 0.6064
# Epoch: 29, Accuracy: 0.6231
# Epoch: 30, Accuracy: 0.6197
# Epoch: 31, Accuracy: 0.6227
# Epoch: 32, Accuracy: 0.6201
# Epoch: 33, Accuracy: 0.6284
# Epoch: 34, Accuracy: 0.6385
# Epoch: 35, Accuracy: 0.6394
# Epoch: 36, Accuracy: 0.6402
# Epoch: 37, Accuracy: 0.6353
# Epoch: 38, Accuracy: 0.6377
# Epoch: 39, Accuracy: 0.6328
# Epoch: 40, Accuracy: 0.6345
# Epoch: 41, Accuracy: 0.6443
# Epoch: 42, Accuracy: 0.6418
# Epoch: 43, Accuracy: 0.6373
# Epoch: 44, Accuracy: 0.6417
# Epoch: 45, Accuracy: 0.6335
# Epoch: 46, Accuracy: 0.6369
# Epoch: 47, Accuracy: 0.6339
# Epoch: 48, Accuracy: 0.6350
# Epoch: 49, Accuracy: 0.6378
# Epoch: 50, Accuracy: 0.6468
# Epoch: 51, Accuracy: 0.6494
# Epoch: 52, Accuracy: 0.7119
# Epoch: 53, Accuracy: 0.7558
# Epoch: 54, Accuracy: 0.7593
# Epoch: 55, Accuracy: 0.7640
# Epoch: 56, Accuracy: 0.8974
# Epoch: 57, Accuracy: 0.9198
# Epoch: 58, Accuracy: 0.7878
# Epoch: 59, Accuracy: 0.8908
# Epoch: 60, Accuracy: 0.9242
# Epoch: 61, Accuracy: 0.9327
# Epoch: 62, Accuracy: 0.9478
# Epoch: 63, Accuracy: 0.9429
# Epoch: 64, Accuracy: 0.8777
# Epoch: 65, Accuracy: 0.8910
# Epoch: 66, Accuracy: 0.9531
# Epoch: 67, Accuracy: 0.9054
# Epoch: 68, Accuracy: 0.9495
# Epoch: 69, Accuracy: 0.9537
# Epoch: 70, Accuracy: 0.9477
# Epoch: 71, Accuracy: 0.9633
# Epoch: 72, Accuracy: 0.9619
# Epoch: 73, Accuracy: 0.9569
# Epoch: 74, Accuracy: 0.9595
# Epoch: 75, Accuracy: 0.9434
# Epoch: 76, Accuracy: 0.9614
# Epoch: 77, Accuracy: 0.9502
# Epoch: 78, Accuracy: 0.9672
# Epoch: 79, Accuracy: 0.9650
# Epoch: 80, Accuracy: 0.9715
# Epoch: 81, Accuracy: 0.9640
# Epoch: 82, Accuracy: 0.9676
# Epoch: 83, Accuracy: 0.9711
# Epoch: 84, Accuracy: 0.9692
# Epoch: 85, Accuracy: 0.9707
# Epoch: 86, Accuracy: 0.9688
# Epoch: 87, Accuracy: 0.9727
# Epoch: 88, Accuracy: 0.9751
# Epoch: 89, Accuracy: 0.9723
# Epoch: 90, Accuracy: 0.9662
# Epoch: 91, Accuracy: 0.9579
# Epoch: 92, Accuracy: 0.9656
# Epoch: 93, Accuracy: 0.9748
# Epoch: 94, Accuracy: 0.9765
# Epoch: 95, Accuracy: 0.9785
# Epoch: 96, Accuracy: 0.9738
# Epoch: 97, Accuracy: 0.9698
# Epoch: 98, Accuracy: 0.9545
# Epoch: 99, Accuracy: 0.9581
# Epoch: 100, Accuracy: 0.9749
# Epoch: 101, Accuracy: 0.9753
# Epoch: 102, Accuracy: 0.9772
# Epoch: 103, Accuracy: 0.9766
# Epoch: 104, Accuracy: 0.9751
# Epoch: 105, Accuracy: 0.9760
# Epoch: 106, Accuracy: 0.9695
# Epoch: 107, Accuracy: 0.9752
# Epoch: 108, Accuracy: 0.9779
# Epoch: 109, Accuracy: 0.9788
# Epoch: 110, Accuracy: 0.9810
# Epoch: 111, Accuracy: 0.9802
# Epoch: 112, Accuracy: 0.9816
# Epoch: 113, Accuracy: 0.9816
# Epoch: 114, Accuracy: 0.9749
# Epoch: 115, Accuracy: 0.9795
# Epoch: 116, Accuracy: 0.9812
# Epoch: 117, Accuracy: 0.9802
# Epoch: 118, Accuracy: 0.9800
# Epoch: 119, Accuracy: 0.9813
# Epoch: 120, Accuracy: 0.9786
# Epoch: 121, Accuracy: 0.9829
# Epoch: 122, Accuracy: 0.9823
# Epoch: 123, Accuracy: 0.9810
# Epoch: 124, Accuracy: 0.9754
# Epoch: 125, Accuracy: 0.9744
# Epoch: 126, Accuracy: 0.9817
# Epoch: 127, Accuracy: 0.9807
# Epoch: 128, Accuracy: 0.9792
# Epoch: 129, Accuracy: 0.9736
# Epoch: 130, Accuracy: 0.9742
# Epoch: 131, Accuracy: 0.9755
# Epoch: 132, Accuracy: 0.9716
# Epoch: 133, Accuracy: 0.9655
# Epoch: 134, Accuracy: 0.9789
# Epoch: 135, Accuracy: 0.9828
# Epoch: 136, Accuracy: 0.9785
# Epoch: 137, Accuracy: 0.9833
# Epoch: 138, Accuracy: 0.9833
# Epoch: 139, Accuracy: 0.9729
# Epoch: 140, Accuracy: 0.9821
# Epoch: 141, Accuracy: 0.9826
# Epoch: 142, Accuracy: 0.9827
# Epoch: 143, Accuracy: 0.9800
# Epoch: 144, Accuracy: 0.9818
# Epoch: 145, Accuracy: 0.9759
# Epoch: 146, Accuracy: 0.9764
# Epoch: 147, Accuracy: 0.9839
# Epoch: 148, Accuracy: 0.9844
# Epoch: 149, Accuracy: 0.9827
# Epoch: 150, Accuracy: 0.9839
# Epoch: 151, Accuracy: 0.9835
# Epoch: 152, Accuracy: 0.9842
# Epoch: 153, Accuracy: 0.9843
# Epoch: 154, Accuracy: 0.9829
# Epoch: 155, Accuracy: 0.9818
# Epoch: 156, Accuracy: 0.9824
# Epoch: 157, Accuracy: 0.9748
# Epoch: 158, Accuracy: 0.9800
# Epoch: 159, Accuracy: 0.9802
# Epoch: 160, Accuracy: 0.9837
# Epoch: 161, Accuracy: 0.9828
# Epoch: 162, Accuracy: 0.9817
# Epoch: 163, Accuracy: 0.9843
# Epoch: 164, Accuracy: 0.9794
# Epoch: 165, Accuracy: 0.9777
# Epoch: 166, Accuracy: 0.9850
# Epoch: 167, Accuracy: 0.9828
# Epoch: 168, Accuracy: 0.9823
# Epoch: 169, Accuracy: 0.9807
# Epoch: 170, Accuracy: 0.9844
# Epoch: 171, Accuracy: 0.9845
# Epoch: 172, Accuracy: 0.9840
# Epoch: 173, Accuracy: 0.9851
# Epoch: 174, Accuracy: 0.9835
# Epoch: 175, Accuracy: 0.9820
# Epoch: 176, Accuracy: 0.9817
# Epoch: 177, Accuracy: 0.9824
# Epoch: 178, Accuracy: 0.9804
# Epoch: 179, Accuracy: 0.9790
# Epoch: 180, Accuracy: 0.9828
# Epoch: 181, Accuracy: 0.9841
# Epoch: 182, Accuracy: 0.9848
# Epoch: 183, Accuracy: 0.9833
# Epoch: 184, Accuracy: 0.9820
# Epoch: 185, Accuracy: 0.9848
# Epoch: 186, Accuracy: 0.9837
# Epoch: 187, Accuracy: 0.9847
# Epoch: 188, Accuracy: 0.9829
# Epoch: 189, Accuracy: 0.9835
# Epoch: 190, Accuracy: 0.9838
# Epoch: 191, Accuracy: 0.9828
# Epoch: 192, Accuracy: 0.9840
# Epoch: 193, Accuracy: 0.9853
# Epoch: 194, Accuracy: 0.9843
# Epoch: 195, Accuracy: 0.9807
# Epoch: 196, Accuracy: 0.9773
# Epoch: 197, Accuracy: 0.9816
# Epoch: 198, Accuracy: 0.9803
# Epoch: 199, Accuracy: 0.9848
# Epoch: 200, Accuracy: 0.9824

# %%
plt.plot(np.arange(len(best_acc)), best_acc)

# %% [markdown]
# # **Load MuonE data and reconstruct tracks**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Circle parameters
num_layers = 14
height, width = 10, 10
#min_curve, max_curve =  1000, 1001 # 15, 50

max_angle = (0.05)*np.pi
feature_scale = 200.

# %%
import numpy as np
import pandas as pd

def readMuonE():

   event_file = "/content/drive/My Drive/MuonE_tracking/hitFile_medium.csv"

   data = pd.read_csv(event_file) 
   # Preview the first 5 lines of the loaded data 
   data.head()

   # Temporary nextZ  (next layer Z)
   layerZ0 =  [-999, -16, -21, 131, 151, 477, 497, 832, 843.7, 1146, 1141, 1252.7, 1266, 1973, 1960 ]



   #X = np.array([[0,0,0]])
   #print(X)
   
   
   iEventLast=data.iat[0,0]
   k=0
   Xcreated=False
   #dataOUTcreated=False
   dataOUT = []

   #iterate over input data
   for k, row in data.iterrows():
     ll=data.iat[k,0]
     #print("counter ",k,ll,iEventLast)
     if ll != iEventLast:

       '''
       for layer in np.arange(num_layers-1):
          print("XX=",layer,X)
          for i in np.argwhere(X[:,2] == layerZ0[layer+1]): 
            for j in np.argwhere(X[:,2] == layerZ0[layer+3]):
               if (X[i, 0] - 20. < X[j, 0] < X[i, 0] + 20.):
                   print("layer, i, j=",layer, i, j)
       '''
#       e = np.array([[i,j] for layer in np.arange(num_layers-1) for i in np.argwhere(X[:,2] == layer+1) for j in np.argwhere(X[:,2] == (layer+2))  if (X[i, 0] - np.tan(max_angle/2) < X[j, 0] < X[i, 0] + np.tan(max_angle/2))]).T.squeeze()

       e = np.array([[i,j] for layer in np.arange(num_layers-1) for i in np.argwhere(X[:,2] == 
              layerZ0[layer+1]) for j in np.argwhere(X[:,2] == layerZ0[layer+3])  if (X[i, 0] - np.tan(max_angle/2)*(layerZ0[layer+3]-layerZ0[layer+1]) < X[j, 0] < X[i, 0] + np.tan(max_angle/2)*(layerZ0[layer+3]-layerZ0[layer+1]))]).T.squeeze()

       #print(X)
       #print("e ",e) 
        # This handles when no edges were constructed. In that case, the randomisation is a do-over
       #try:
       y = np.array([int(i[1] == j[1]) for i,j in zip(X[e[0]], X[e[1]])])
       #     print("y = ",y)     
       #     break
       #except:
       #     pass

       #print("y = ",y) 
       #if iter is not None and num_samples is not None:
       #     out.update(progress(iter, num_samples))    


       X = np.array([X[:,2], X[:,0]]).T / feature_scale

       dataEvent = Data(x = torch.from_numpy(X).float(), edge_index = torch.from_numpy(e), y = torch.from_numpy(y), pid = torch.from_numpy(X[:,1]))

       #plot_toy_graph(dataEvent, 0.2)

       dataOUT.append(dataEvent)
#       if dataOUTcreated:
#         dataOUT = dataOUT.append(dataEvent)
#       else:
#         dataOUT = dataEvent 
#         dataOUTcreated = True

       Xcreated = False  
       iEventLast = ll

     #print(len(X)) 
     #print(k,ll,data.iat[k,2],Xcreated) 
     if data.iat[k,2]==0 and data.iat[k,5]<3 and data.iat[k,5]>0: # select X-hit and trackID=0,1,2
        if Xcreated:
          X = np.append(X,np.array([[data.iat[k,1], data.iat[k,5], data.iat[k,3]  ]]),axis=0)
        else:
          X = np.array([[data.iat[k,1], data.iat[k,5], data.iat[k,3]  ]]) 
          Xcreated=True
          #print("X created ",X)
     
   return dataOUT

# %%
# Read data and prepare for training

data = readMuonE()


# split data into training and test datasets
train_dataset = []
test_dataset = []
for k in range(len(data)):
  if (k%2 == 0):
    test_dataset.append(data[k])
  else:
    train_dataset.append(data[k])


train_loader = DataLoader(train_dataset, batch_size=100, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=100, shuffle=True)    

# Display few events
for k in range(10):
   plot_toy_graph(train_loader.dataset[k], 0.2)


print("Fake / True = ", (len(train_dataset[0].y) - train_dataset[0].y.sum().item()) / train_dataset[0].y.sum().item())

print("Training dataset (events): ",len(train_dataset))
print("Test dataset (events): ",len(test_dataset))
# Out:
# Fake / True =  1.0
# Training dataset (events):  4999
# Test dataset (events):  5000

# %% [markdown]
# # **Simple GNN**

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
m_configs = {"input_dim": 2, "hidden_node_dim": 64, "hidden_edge_dim": 64, "in_layers": 2, "node_layers": 4, "edge_layers": 4, "n_graph_iters": 1, "layer_norm": True}
model = MPNN_Network(**m_configs).to(device)
model
# Out:
# MPNN_Network(
#   (node_encoder): Sequential(
#     (0): Linear(in_features=2, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ReLU()
#   )
#   (edge_network): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=64, bias=True)
#     (7): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (8): ReLU()
#     (9): Linear(in_features=64, out_features=64, bias=True)
#     (10): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (11): ReLU()
#   )
#   (node_network): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=64, bias=True)
#     (7): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (8): ReLU()
#     (9): Linear(in_features=64, out_features=64, bias=True)
#     (10): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (11): ReLU()
#   )
#   (edge_classifier): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %%
t_loss_v = []
t_acc_v = []
v_loss_v = []
v_acc_v = []
ep = 0

# %% [markdown]
# We set a weight value that is more or less the (fake / true) ratio found above. This forces the loss function to punish incorrectly classified true edges more severely. It rebalances the distribution as if there was a 1:1 true:fake ratio.

# %%
weight = 2

m_configs = {"input_dim": 2, "hidden_node_dim": 16, "hidden_edge_dim": 16, "in_layers": 1, "node_layers": 2, "edge_layers": 2, "n_graph_iters": 6, "layer_norm": True}
model = MPNN_Network(**m_configs).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-3, amsgrad=True)

for epoch in range(500):
    ep += 1  
    model.train()
    acc, total_loss = train(model, train_loader, optimizer)
    t_loss_v.append(total_loss)
    t_acc_v.append(acc)

    model.eval()
    acc, total_loss = evaluate(model, test_loader)
    v_loss_v.append(total_loss)
    v_acc_v.append(acc)

    print('Epoch: {}, Accuracy: {:.4f}'.format(ep, acc))
# Out:
# Epoch: 1, Accuracy: 0.5384
# Epoch: 2, Accuracy: 0.5384
# Epoch: 3, Accuracy: 0.5384
# Epoch: 4, Accuracy: 0.5384
# Epoch: 5, Accuracy: 0.5384
# Epoch: 6, Accuracy: 0.5384
# Epoch: 7, Accuracy: 0.5384
# Epoch: 8, Accuracy: 0.5475
# Epoch: 9, Accuracy: 0.5384
# Epoch: 10, Accuracy: 0.5384
# Epoch: 11, Accuracy: 0.5384
# Epoch: 12, Accuracy: 0.5384
# Epoch: 13, Accuracy: 0.5475
# Epoch: 14, Accuracy: 0.5475
# Epoch: 15, Accuracy: 0.5475
# Epoch: 16, Accuracy: 0.5475
# Epoch: 17, Accuracy: 0.5475
# Epoch: 18, Accuracy: 0.5475
# Epoch: 19, Accuracy: 0.5475
# Epoch: 20, Accuracy: 0.5384
# Epoch: 21, Accuracy: 0.5384
# Epoch: 22, Accuracy: 0.5384
# Epoch: 23, Accuracy: 0.5384
# Epoch: 24, Accuracy: 0.5384
# Epoch: 25, Accuracy: 0.5384
# Epoch: 26, Accuracy: 0.5384
# Epoch: 27, Accuracy: 0.5384
# Epoch: 28, Accuracy: 0.5475
# Epoch: 29, Accuracy: 0.5384
# Epoch: 30, Accuracy: 0.5475
# Epoch: 31, Accuracy: 0.5475
# Epoch: 32, Accuracy: 0.5475
# Epoch: 33, Accuracy: 0.5475
# Epoch: 34, Accuracy: 0.5475
# Epoch: 35, Accuracy: 0.5475
# Epoch: 36, Accuracy: 0.5384
# Epoch: 37, Accuracy: 0.5475
# Epoch: 38, Accuracy: 0.5475
# Epoch: 39, Accuracy: 0.5475
# Epoch: 40, Accuracy: 0.5475
# Epoch: 41, Accuracy: 0.5475
# Epoch: 42, Accuracy: 0.5475
# Epoch: 43, Accuracy: 0.5475
# Epoch: 44, Accuracy: 0.5475
# Epoch: 45, Accuracy: 0.5475
# Epoch: 46, Accuracy: 0.5475
# Epoch: 47, Accuracy: 0.5475
# Epoch: 48, Accuracy: 0.5475
# Epoch: 49, Accuracy: 0.5475
# Epoch: 50, Accuracy: 0.5475
# Epoch: 51, Accuracy: 0.5475
# Epoch: 52, Accuracy: 0.5475
# Epoch: 53, Accuracy: 0.5475
# Epoch: 54, Accuracy: 0.5475
# Epoch: 55, Accuracy: 0.5475
# Epoch: 56, Accuracy: 0.5475
# Epoch: 57, Accuracy: 0.5475
# Epoch: 58, Accuracy: 0.5475
# Epoch: 59, Accuracy: 0.5475
# Epoch: 60, Accuracy: 0.5475
# Epoch: 61, Accuracy: 0.5475
# Epoch: 62, Accuracy: 0.5475
# Epoch: 63, Accuracy: 0.5475
# Epoch: 64, Accuracy: 0.5475
# Epoch: 65, Accuracy: 0.5475
# Epoch: 66, Accuracy: 0.5475
# Epoch: 67, Accuracy: 0.5475
# Epoch: 68, Accuracy: 0.5475
# Epoch: 69, Accuracy: 0.5475
# Epoch: 70, Accuracy: 0.5475
# Epoch: 71, Accuracy: 0.5475
# Epoch: 72, Accuracy: 0.5475
# Epoch: 73, Accuracy: 0.5475
# Epoch: 74, Accuracy: 0.5475
# Epoch: 75, Accuracy: 0.5475
# Epoch: 76, Accuracy: 0.5475
# Epoch: 77, Accuracy: 0.5475
# Epoch: 78, Accuracy: 0.5475
# Epoch: 79, Accuracy: 0.5475
# Epoch: 80, Accuracy: 0.5475
# Epoch: 81, Accuracy: 0.5475
# Epoch: 82, Accuracy: 0.5475
# Epoch: 83, Accuracy: 0.5475
# Epoch: 84, Accuracy: 0.5475
# Epoch: 85, Accuracy: 0.5475
# Epoch: 86, Accuracy: 0.5475
# Epoch: 87, Accuracy: 0.5475
# Epoch: 88, Accuracy: 0.5475
# Epoch: 89, Accuracy: 0.5475
# Epoch: 90, Accuracy: 0.5475
# Epoch: 91, Accuracy: 0.5475
# Epoch: 92, Accuracy: 0.5475
# Epoch: 93, Accuracy: 0.5475
# Epoch: 94, Accuracy: 0.5475
# Epoch: 95, Accuracy: 0.5475
# Epoch: 96, Accuracy: 0.5475
# Epoch: 97, Accuracy: 0.5475
# Epoch: 98, Accuracy: 0.5475
# Epoch: 99, Accuracy: 0.5475
# Epoch: 100, Accuracy: 0.5475
# Epoch: 101, Accuracy: 0.5475
# Epoch: 102, Accuracy: 0.5475
# Epoch: 103, Accuracy: 0.5475
# Epoch: 104, Accuracy: 0.5475
# Epoch: 105, Accuracy: 0.5475
# Epoch: 106, Accuracy: 0.5475
# Epoch: 107, Accuracy: 0.5475
# Epoch: 108, Accuracy: 0.5475
# Epoch: 109, Accuracy: 0.5475
# Epoch: 110, Accuracy: 0.5475
# Epoch: 111, Accuracy: 0.5475
# Epoch: 112, Accuracy: 0.5475
# Epoch: 113, Accuracy: 0.5475
# Epoch: 114, Accuracy: 0.5475
# Epoch: 115, Accuracy: 0.5475
# Epoch: 116, Accuracy: 0.5475
# Epoch: 117, Accuracy: 0.5475
# Epoch: 118, Accuracy: 0.5475
# Epoch: 119, Accuracy: 0.5475
# Epoch: 120, Accuracy: 0.5475
# Epoch: 121, Accuracy: 0.5475
# Epoch: 122, Accuracy: 0.5475
# Epoch: 123, Accuracy: 0.5475
# Epoch: 124, Accuracy: 0.5475
# Epoch: 125, Accuracy: 0.5475
# Epoch: 126, Accuracy: 0.5475
# Epoch: 127, Accuracy: 0.5475
# Epoch: 128, Accuracy: 0.5475
# Epoch: 129, Accuracy: 0.5475
# Epoch: 130, Accuracy: 0.5475
# Epoch: 131, Accuracy: 0.5475
# Epoch: 132, Accuracy: 0.5475
# Epoch: 133, Accuracy: 0.5475
# Epoch: 134, Accuracy: 0.5475
# Epoch: 135, Accuracy: 0.5475
# Epoch: 136, Accuracy: 0.5475
# Epoch: 137, Accuracy: 0.5475
# Epoch: 138, Accuracy: 0.5475
# Epoch: 139, Accuracy: 0.5475
# Epoch: 140, Accuracy: 0.5475
# Epoch: 141, Accuracy: 0.5475
# Epoch: 142, Accuracy: 0.5475
# Epoch: 143, Accuracy: 0.5475
# Epoch: 144, Accuracy: 0.5475
# Epoch: 145, Accuracy: 0.5475
# Epoch: 146, Accuracy: 0.5475
# Epoch: 147, Accuracy: 0.5475
# Epoch: 148, Accuracy: 0.5475
# Epoch: 149, Accuracy: 0.5475
# Epoch: 150, Accuracy: 0.5475
# Epoch: 151, Accuracy: 0.5475
# Epoch: 152, Accuracy: 0.5475
# Epoch: 153, Accuracy: 0.5475
# Epoch: 154, Accuracy: 0.5475
# Epoch: 155, Accuracy: 0.5475
# Epoch: 156, Accuracy: 0.5475
# Epoch: 157, Accuracy: 0.5475
# Epoch: 158, Accuracy: 0.5475
# Epoch: 159, Accuracy: 0.5475
# Epoch: 160, Accuracy: 0.5475
# Epoch: 161, Accuracy: 0.5475
# Epoch: 162, Accuracy: 0.5475
# Epoch: 163, Accuracy: 0.5475
# Epoch: 164, Accuracy: 0.5475
# Epoch: 165, Accuracy: 0.5475
# Epoch: 166, Accuracy: 0.5475
# Epoch: 167, Accuracy: 0.5384
# Epoch: 168, Accuracy: 0.5384
# Epoch: 169, Accuracy: 0.5384
# Epoch: 170, Accuracy: 0.5475
# Epoch: 171, Accuracy: 0.5475
# Epoch: 172, Accuracy: 0.5384
# Epoch: 173, Accuracy: 0.5384
# Epoch: 174, Accuracy: 0.5384
# Epoch: 175, Accuracy: 0.5384
# Epoch: 176, Accuracy: 0.5384
# Epoch: 177, Accuracy: 0.5384
# Epoch: 178, Accuracy: 0.5384
# Epoch: 179, Accuracy: 0.5384
# Epoch: 180, Accuracy: 0.5384
# Epoch: 181, Accuracy: 0.5384
# Epoch: 182, Accuracy: 0.5384
# Epoch: 183, Accuracy: 0.5384
# Epoch: 184, Accuracy: 0.5384
# Epoch: 185, Accuracy: 0.5384
# Epoch: 186, Accuracy: 0.5384
# Epoch: 187, Accuracy: 0.5384
# Epoch: 188, Accuracy: 0.5475
# Epoch: 189, Accuracy: 0.5475
# Epoch: 190, Accuracy: 0.5475
# Epoch: 191, Accuracy: 0.5475
# Epoch: 192, Accuracy: 0.5475
# Epoch: 193, Accuracy: 0.5475
# Epoch: 194, Accuracy: 0.5475
# Epoch: 195, Accuracy: 0.5475
# Epoch: 196, Accuracy: 0.5475
# Epoch: 197, Accuracy: 0.5475
# Epoch: 198, Accuracy: 0.5475
# Epoch: 199, Accuracy: 0.5475
# Epoch: 200, Accuracy: 0.5475
# Epoch: 201, Accuracy: 0.5475
# Epoch: 202, Accuracy: 0.5475
# Epoch: 203, Accuracy: 0.5475
# Epoch: 204, Accuracy: 0.5475
# Epoch: 205, Accuracy: 0.5475
# Epoch: 206, Accuracy: 0.5475
# Epoch: 207, Accuracy: 0.5475
# Epoch: 208, Accuracy: 0.5475
# Epoch: 209, Accuracy: 0.5475
# Epoch: 210, Accuracy: 0.5475
# Epoch: 211, Accuracy: 0.5475
# Epoch: 212, Accuracy: 0.5475
# Epoch: 213, Accuracy: 0.5475
# Epoch: 214, Accuracy: 0.5475
# Epoch: 215, Accuracy: 0.5475
# Epoch: 216, Accuracy: 0.5475
# Epoch: 217, Accuracy: 0.5475
# Epoch: 218, Accuracy: 0.5475
# Epoch: 219, Accuracy: 0.5475
# Epoch: 220, Accuracy: 0.5475
# Epoch: 221, Accuracy: 0.5475
# Epoch: 222, Accuracy: 0.5475
# Epoch: 223, Accuracy: 0.5475
# Epoch: 224, Accuracy: 0.5475
# Epoch: 225, Accuracy: 0.5475
# Epoch: 226, Accuracy: 0.5475
# Epoch: 227, Accuracy: 0.5475
# Epoch: 228, Accuracy: 0.5475
# Epoch: 229, Accuracy: 0.5475
# Epoch: 230, Accuracy: 0.5475
# Epoch: 231, Accuracy: 0.5475
# Epoch: 232, Accuracy: 0.5475
# Epoch: 233, Accuracy: 0.5475
# Epoch: 234, Accuracy: 0.5475
# Epoch: 235, Accuracy: 0.5475
# Epoch: 236, Accuracy: 0.5475
# Epoch: 237, Accuracy: 0.5475
# Epoch: 238, Accuracy: 0.5475
# Epoch: 239, Accuracy: 0.5475
# Epoch: 240, Accuracy: 0.5475
# Epoch: 241, Accuracy: 0.5475
# Epoch: 242, Accuracy: 0.5475
# Epoch: 243, Accuracy: 0.5475
# Epoch: 244, Accuracy: 0.5475
# Epoch: 245, Accuracy: 0.5475
# Epoch: 246, Accuracy: 0.5475
# Epoch: 247, Accuracy: 0.5475
# Epoch: 248, Accuracy: 0.5475
# Epoch: 249, Accuracy: 0.5475
# Epoch: 250, Accuracy: 0.5475
# Epoch: 251, Accuracy: 0.5475
# Epoch: 252, Accuracy: 0.5475
# Epoch: 253, Accuracy: 0.5475
# Epoch: 254, Accuracy: 0.5475
# Epoch: 255, Accuracy: 0.5475
# Epoch: 256, Accuracy: 0.5475
# Epoch: 257, Accuracy: 0.5475
# Epoch: 258, Accuracy: 0.5475
# Epoch: 259, Accuracy: 0.5475
# Epoch: 260, Accuracy: 0.5475
# Epoch: 261, Accuracy: 0.5475
# Epoch: 262, Accuracy: 0.5475
# Epoch: 263, Accuracy: 0.5475
# Epoch: 264, Accuracy: 0.5475
# Epoch: 265, Accuracy: 0.5475
# Epoch: 266, Accuracy: 0.5475
# Epoch: 267, Accuracy: 0.5475
# Epoch: 268, Accuracy: 0.5475
# Epoch: 269, Accuracy: 0.5475
# Epoch: 270, Accuracy: 0.5475
# Epoch: 271, Accuracy: 0.5475
# Epoch: 272, Accuracy: 0.5475
# Epoch: 273, Accuracy: 0.5475
# Epoch: 274, Accuracy: 0.5475
# Epoch: 275, Accuracy: 0.5475
# Epoch: 276, Accuracy: 0.5475
# Epoch: 277, Accuracy: 0.5475
# Epoch: 278, Accuracy: 0.5475
# Epoch: 279, Accuracy: 0.5475
# Epoch: 280, Accuracy: 0.5475
# Epoch: 281, Accuracy: 0.5475
# Epoch: 282, Accuracy: 0.5475
# Epoch: 283, Accuracy: 0.5475
# Epoch: 284, Accuracy: 0.5475
# Epoch: 285, Accuracy: 0.5475
# Epoch: 286, Accuracy: 0.5475
# Epoch: 287, Accuracy: 0.5475
# Epoch: 288, Accuracy: 0.5475
# Epoch: 289, Accuracy: 0.5475
# Epoch: 290, Accuracy: 0.5475
# Epoch: 291, Accuracy: 0.5475
# Epoch: 292, Accuracy: 0.5475
# Epoch: 293, Accuracy: 0.5475
# Epoch: 294, Accuracy: 0.5475
# Epoch: 295, Accuracy: 0.5475
# Epoch: 296, Accuracy: 0.5475
# Epoch: 297, Accuracy: 0.5475
# Epoch: 298, Accuracy: 0.5475
# Epoch: 299, Accuracy: 0.5475
# Epoch: 300, Accuracy: 0.5384
# Epoch: 301, Accuracy: 0.5384
# Epoch: 302, Accuracy: 0.5384
# Epoch: 303, Accuracy: 0.5384
# Epoch: 304, Accuracy: 0.5475
# Epoch: 305, Accuracy: 0.5475
# Epoch: 306, Accuracy: 0.5475
# Epoch: 307, Accuracy: 0.5475
# Epoch: 308, Accuracy: 0.5475
# Epoch: 309, Accuracy: 0.5475
# Epoch: 310, Accuracy: 0.5475
# Epoch: 311, Accuracy: 0.5475
# Epoch: 312, Accuracy: 0.5475
# Epoch: 313, Accuracy: 0.5475
# Epoch: 314, Accuracy: 0.5475
# Epoch: 315, Accuracy: 0.5475
# Epoch: 316, Accuracy: 0.5475
# Epoch: 317, Accuracy: 0.5475
# Epoch: 318, Accuracy: 0.5475
# Epoch: 319, Accuracy: 0.5475
# Epoch: 320, Accuracy: 0.5475
# Epoch: 321, Accuracy: 0.5475
# Epoch: 322, Accuracy: 0.5475
# Epoch: 323, Accuracy: 0.5475
# Epoch: 324, Accuracy: 0.5475
# Epoch: 325, Accuracy: 0.5475
# Epoch: 326, Accuracy: 0.5475
# Epoch: 327, Accuracy: 0.5475
# Epoch: 328, Accuracy: 0.5475
# Epoch: 329, Accuracy: 0.5475
# Epoch: 330, Accuracy: 0.5475
# Epoch: 331, Accuracy: 0.5475
# Epoch: 332, Accuracy: 0.5475
# Epoch: 333, Accuracy: 0.5475
# Epoch: 334, Accuracy: 0.5475
# Epoch: 335, Accuracy: 0.5475
# Epoch: 336, Accuracy: 0.5475
# Epoch: 337, Accuracy: 0.5475
# Epoch: 338, Accuracy: 0.5475
# Epoch: 339, Accuracy: 0.5475
# Epoch: 340, Accuracy: 0.5475
# Epoch: 341, Accuracy: 0.5475
# Epoch: 342, Accuracy: 0.5475
# Epoch: 343, Accuracy: 0.5475
# Epoch: 344, Accuracy: 0.5475
# Epoch: 345, Accuracy: 0.5475
# Epoch: 346, Accuracy: 0.5475
# Epoch: 347, Accuracy: 0.5475
# Epoch: 348, Accuracy: 0.5475
# Epoch: 349, Accuracy: 0.5475
# Epoch: 350, Accuracy: 0.5475
# Epoch: 351, Accuracy: 0.5475
# Epoch: 352, Accuracy: 0.5475
# Epoch: 353, Accuracy: 0.5475
# Epoch: 354, Accuracy: 0.5475
# Epoch: 355, Accuracy: 0.5475
# Epoch: 356, Accuracy: 0.5475
# Epoch: 357, Accuracy: 0.5475
# Epoch: 358, Accuracy: 0.5475
# Epoch: 359, Accuracy: 0.5475
# Epoch: 360, Accuracy: 0.5475
# Epoch: 361, Accuracy: 0.5475
# Epoch: 362, Accuracy: 0.5475
# Epoch: 363, Accuracy: 0.5475
# Epoch: 364, Accuracy: 0.5475
# Epoch: 365, Accuracy: 0.5475
# Epoch: 366, Accuracy: 0.5475
# Epoch: 367, Accuracy: 0.5475
# Epoch: 368, Accuracy: 0.5475
# Epoch: 369, Accuracy: 0.5475
# Epoch: 370, Accuracy: 0.5475
# Epoch: 371, Accuracy: 0.5475
# Epoch: 372, Accuracy: 0.5475
# Epoch: 373, Accuracy: 0.5475
# Epoch: 374, Accuracy: 0.5475
# Epoch: 375, Accuracy: 0.5475
# Epoch: 376, Accuracy: 0.5475
# Epoch: 377, Accuracy: 0.5475
# Epoch: 378, Accuracy: 0.5475
# Epoch: 379, Accuracy: 0.5475
# Epoch: 380, Accuracy: 0.5475
# Epoch: 381, Accuracy: 0.5475
# Epoch: 382, Accuracy: 0.5475
# Epoch: 383, Accuracy: 0.5475
# Epoch: 384, Accuracy: 0.5475
# Epoch: 385, Accuracy: 0.5475
# Epoch: 386, Accuracy: 0.5475
# Epoch: 387, Accuracy: 0.5475
# Epoch: 388, Accuracy: 0.5475
# Epoch: 389, Accuracy: 0.5475
# Epoch: 390, Accuracy: 0.5475
# Epoch: 391, Accuracy: 0.5475
# Epoch: 392, Accuracy: 0.5475
# Epoch: 393, Accuracy: 0.5475
# Epoch: 394, Accuracy: 0.5475
# Epoch: 395, Accuracy: 0.5475
# Epoch: 396, Accuracy: 0.5475
# Epoch: 397, Accuracy: 0.5475
# Epoch: 398, Accuracy: 0.5475
# Epoch: 399, Accuracy: 0.5475
# Epoch: 400, Accuracy: 0.5475
# Epoch: 401, Accuracy: 0.5475
# Epoch: 402, Accuracy: 0.5475
# Epoch: 403, Accuracy: 0.5475
# Epoch: 404, Accuracy: 0.5475
# Epoch: 405, Accuracy: 0.5475
# Epoch: 406, Accuracy: 0.5475
# Epoch: 407, Accuracy: 0.5475
# Epoch: 408, Accuracy: 0.5475
# Epoch: 409, Accuracy: 0.5475
# Epoch: 410, Accuracy: 0.5475
# Epoch: 411, Accuracy: 0.5475
# Epoch: 412, Accuracy: 0.5475
# Epoch: 413, Accuracy: 0.5475
# Epoch: 414, Accuracy: 0.5475
# Epoch: 415, Accuracy: 0.5475
# Epoch: 416, Accuracy: 0.5475
# Epoch: 417, Accuracy: 0.5475
# Epoch: 418, Accuracy: 0.5475
# Epoch: 419, Accuracy: 0.5475
# Epoch: 420, Accuracy: 0.5475
# Epoch: 421, Accuracy: 0.5475
# Epoch: 422, Accuracy: 0.5475
# Epoch: 423, Accuracy: 0.5475
# Epoch: 424, Accuracy: 0.5475
# Epoch: 425, Accuracy: 0.5475
# Epoch: 426, Accuracy: 0.5475
# Epoch: 427, Accuracy: 0.5475
# Epoch: 428, Accuracy: 0.5475
# Epoch: 429, Accuracy: 0.5475
# Epoch: 430, Accuracy: 0.5475
# Epoch: 431, Accuracy: 0.5475
# Epoch: 432, Accuracy: 0.5475
# Epoch: 433, Accuracy: 0.5475
# Epoch: 434, Accuracy: 0.5475
# Epoch: 435, Accuracy: 0.5475
# Epoch: 436, Accuracy: 0.5475
# Epoch: 437, Accuracy: 0.5475
# Epoch: 438, Accuracy: 0.5475
# Epoch: 439, Accuracy: 0.5475
# Epoch: 440, Accuracy: 0.5475
# Epoch: 441, Accuracy: 0.5475
# Epoch: 442, Accuracy: 0.5475
# Epoch: 443, Accuracy: 0.5475
# Epoch: 444, Accuracy: 0.5475
# Epoch: 445, Accuracy: 0.5475
# Epoch: 446, Accuracy: 0.5475
# Epoch: 447, Accuracy: 0.5475
# Epoch: 448, Accuracy: 0.5475
# Epoch: 449, Accuracy: 0.5475
# Epoch: 450, Accuracy: 0.5475
# Epoch: 451, Accuracy: 0.5475
# Epoch: 452, Accuracy: 0.5475
# Epoch: 453, Accuracy: 0.5475
# Epoch: 454, Accuracy: 0.5475
# Epoch: 455, Accuracy: 0.5475
# Epoch: 456, Accuracy: 0.5475
# Epoch: 457, Accuracy: 0.5475
# Epoch: 458, Accuracy: 0.5475
# Epoch: 459, Accuracy: 0.5475
# Epoch: 460, Accuracy: 0.5475
# Epoch: 461, Accuracy: 0.5475
# Epoch: 462, Accuracy: 0.5475
# Epoch: 463, Accuracy: 0.5475
# Epoch: 464, Accuracy: 0.5475
# Epoch: 465, Accuracy: 0.5475
# Epoch: 466, Accuracy: 0.5475
# Epoch: 467, Accuracy: 0.5475
# Epoch: 468, Accuracy: 0.5475
# Epoch: 469, Accuracy: 0.5475
# Epoch: 470, Accuracy: 0.5475
# Epoch: 471, Accuracy: 0.5475
# Epoch: 472, Accuracy: 0.5475
# Epoch: 473, Accuracy: 0.5475
# Epoch: 474, Accuracy: 0.5475
# Epoch: 475, Accuracy: 0.5475
# Epoch: 476, Accuracy: 0.5475
# Epoch: 477, Accuracy: 0.5475
# Epoch: 478, Accuracy: 0.5475
# Epoch: 479, Accuracy: 0.5475
# Epoch: 480, Accuracy: 0.5475
# Epoch: 481, Accuracy: 0.5475
# Epoch: 482, Accuracy: 0.5475
# Epoch: 483, Accuracy: 0.5475
# Epoch: 484, Accuracy: 0.5475
# Epoch: 485, Accuracy: 0.5475
# Epoch: 486, Accuracy: 0.5475
# Epoch: 487, Accuracy: 0.5475
# Epoch: 488, Accuracy: 0.5475
# Epoch: 489, Accuracy: 0.5475
# Epoch: 490, Accuracy: 0.5475
# Epoch: 491, Accuracy: 0.5475
# Epoch: 492, Accuracy: 0.5475
# Epoch: 493, Accuracy: 0.5475
# Epoch: 494, Accuracy: 0.5475
# Epoch: 495, Accuracy: 0.5475
# Epoch: 496, Accuracy: 0.5475
# Epoch: 497, Accuracy: 0.5475
# Epoch: 498, Accuracy: 0.5475
# Epoch: 499, Accuracy: 0.5475
# Epoch: 500, Accuracy: 0.5475

# %%
fig, axs = plt.subplots(1, 2, constrained_layout=True, figsize=(10, 5))
axs[0].plot(np.arange(len(t_loss_v)), t_loss_v, np.arange(len(t_acc_v)), t_acc_v)
axs[0].set_title("Training loss and accuracy")
axs[0].set_yscale("linear")
axs[1].plot(np.arange(len(v_loss_v)), v_loss_v, np.arange(len(v_acc_v)), v_acc_v)
axs[1].set_title("Validation loss and accuracy")
axs[1].set_yscale("linear")

# %% [markdown]
# ### Did it work?

# %% [markdown]
# ![alt text](https://)Running the above with 1 graph iteration gives me about 80% accuracy in 200 epochs.

# %%
for i in range(20):
  data = train_loader.dataset[i].to(device)
  preds = torch.sigmoid(model(data)).to('cpu')
  plot_toy_classified(data.to('cpu'), preds, cut = 0.6)
  #plot_toy_graph(train_loader.dataset[2],0.2)
